# %%
import pandas as pd 

clinical = pd.read_csv("data/raw/luad_tcga_pan_can_atlas_2018_clinical_data.tsv", sep="\t") 
clinical.head()
# Out:
#                        Study ID    Patient ID        Sample ID  Diagnosis Age  \
# 0  luad_tcga_pan_can_atlas_2018  TCGA-05-4244  TCGA-05-4244-01           70.0
# 1  luad_tcga_pan_can_atlas_2018  TCGA-05-4249  TCGA-05-4249-01           67.0
# 2  luad_tcga_pan_can_atlas_2018  TCGA-05-4250  TCGA-05-4250-01           79.0
# 3  luad_tcga_pan_can_atlas_2018  TCGA-05-4382  TCGA-05-4382-01           68.0
# 4  luad_tcga_pan_can_atlas_2018  TCGA-05-4384  TCGA-05-4384-01           66.0
#
#   Neoplasm Disease Stage American Joint Committee on Cancer Code  \
# 0                                           STAGE IV
# 1                                           STAGE IB
# 2                                         STAGE IIIA
# 3                                           STAGE IB
# 4                                         STAGE IIIA
#
#   American Joint Committee on Cancer Publication Version Type  \
# 0                                                6TH
# ...
